# %%
import bs4
from bs4 import BeautifulSoup as bs
import requests

# %%
link='https://www.flipkart.com/search?q=tv&as=on&as-show=on&otracker=AS_Query_TrendingAutoSuggest_8_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_8_0_na_na_na&as-pos=8&as-type=TRENDING&suggestionId=tv&requestId=9c9fa553-b7e5-454b-a65b-bbb7a9c74a29'

# %%
page = requests.get(link)

# %%
page.content
soup = bs(page.content, 'html.parser')
#it gives us the visual representation of data
print(soup.prettify())

# %%
products=[]              #List to store the name of the product
prices=[]                #List to store price of the product
apps = []                #List to store supported apps                
os = []                  #List to store operating system
for data in soup.findAll('div',class_='_3pLy-c row'):
        names=data.find('div', attrs={'class':'_4rR01T'})
        price=data.find('div', attrs={'class':'_30jeq3 _1_WHN1'})
        rating=data.find('div', attrs={'class':'_3LWZlK'})
        specification = data.find('div', attrs={'class':'fMghEO'})
        products.append(names.text) # Add product name to list
        prices.append(price.text) # Add price to list

        for each in specification:
            col=each.find_all('li', attrs={'class':'rgWa7D'})
            app =col[0].text
            apps.append(app)
            os_ = col[1].text
            os.append(os_)

# %%
print(len(products))
print(len(os))
print(len(prices))
print(len(apps))
# Out:
# 24
# 24
# 24
# 24

# %%
import pandas as pd
df=pd.DataFrame({'Product Name':products,'Supported_apps':apps,'OS':os,'Price':prices})
df
# Out:
#                                          Product Name  \
# 0   Yuwa 80 cm (32 inch) HD Ready LED Smart Androi...
# 1   T-Series 80 cm (32 inch) HD Ready LED Smart An...
# 2      LG 80 cm (32 inch) HD Ready LED Smart WebOS TV
# 3   realme 80 cm (32 inch) HD Ready LED Smart Andr...
# 4   realme 100.3 cm (40 inch) Full HD LED Smart An...
# 5   Mi 5A 80 cm (32 inch) HD Ready LED Smart Andro...
# 6   OnePlus Y1 80 cm (32 inch) HD Ready LED Smart ...
# 7   SAMSUNG 80 cm (32 Inch) HD Ready LED Smart Tiz...
# 8   Thomson Alpha 80 cm (32 inch) HD Ready LED Sma...
# 9   iFFALCON by TCL F53 79.97 cm (32 inch) HD Read...
# 10  Infinix Y1 80 cm (32 inch) HD Ready LED Smart ...
# 11  OnePlus Y1 100 cm (40 inch) Full HD LED Smart ...
# 12  realme NEO 80 cm (32 inch) HD Ready LED Smart ...
# 13  Mi 5A 108 cm (43 inch) Full HD LED Smart Andro...
# 14  OnePlus Y1S 108 cm (43 inch) Full HD LED Smart...
# 15  realme 108 cm (43 inch) Full HD LED Smart Andr...
# 16  OnePlus Y1S 80 cm (32 inch) HD Ready LED Smart...
# 17  realme 126 cm (50 inch) Ultra HD (4K) LED Smar...
# 18  Vu 108 cm (43 inch) Ultra HD (4K) LED Smart We...
# 19  Mi 5A 100 cm (40 inch) Full HD LED Smart Andro...
# 20  Vu 138 cm (55 inch) Ultra HD (4K) LED Smart We...
# 21  Mi 4A Horizon Edition 80 cm (32 inch) HD Ready...
# 22  iFFALCON by TCL U62 108 cm (43 inch) Ultra HD ...
# 23  SAMSUNG 80 cm (32 inch) HD Ready LED Smart Tiz...
#
#                  Supported_apps                                OS    Price
# 0     Operating System: Android        HD Ready 1366 x 768 Pixels  ₹10,449
# 1     Operating System: Android        HD Ready 1366 x 768 Pixels  ₹10,490
# 2       Operating System: WebOS        HD Ready 1366 x 768 Pixels  ₹12,990
# 3     Operating System: Android        HD Ready 1366 x 768 Pixels  ₹11,999
# 4     Operating System: Android        Full HD 1920 x 1080 Pixels  ₹17,999
# 5     Operating System: Android        HD Ready 1366 x 768 Pixels  ₹13,999
# 6     Operating System: Android        HD Ready 1366 x 768 Pixels  ₹12,999
# 7       Operating System: Tizen        HD Ready 1366 x 768 Pixels  ₹13,490
# 8       Operating System: Linux        HD Ready 1366 x 768 Pixels   ₹7,999
# 9     Operating System: Android        HD Ready 1366 x 768 Pixels   ₹8,999
# 10      Operating System: Linux        HD Ready 1366 x 768 Pixels   ₹8,499
# 11    Operating System: Android        Full HD 1920 x 1080 Pixels  ₹19,999
# 12      Operating System: Linux        HD Ready 1366 x 768 Pixels  ₹10,999
# 13    Operating System: Android        Full HD 1920 x 1080 Pixels  ₹22,781
# 14    Operating System: Android        Full HD 1920 x 1080 Pixels  ₹23,999
# 15    Operating System: Android        Full HD 1920 x 1080 Pixels  ₹20,999
# 16    Operating System: Android        HD Ready 1366 x 768 Pixels  ₹14,999
# 17    Operating System: Android  Ultra HD (4K) 3840 x 2160 Pixels  ₹28,999
# 18      Operating System: WebOS  Ultra HD (4K) 3840 x 2160 Pixels  ₹19,999
# 19    Operating System: Android        Full HD 1920 x 1080 Pixels  ₹20,367
# 20      Operating System: WebOS  Ultra HD (4K) 3840 x 2160 Pixels  ₹28,671
# 21    Operating System: Android        HD Ready 1366 x 768 Pixels  ₹11,999
# 22  Operating System: Google TV  Ultra HD (4K) 3840 x 2160 Pixels  ₹18,999
# 23      Operating System: Tizen        HD Ready 1366 x 768 Pixels  ₹13,490

# %%
df.to_csv('file1.csv', header=False, index=False)
